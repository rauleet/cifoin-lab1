# %% [markdown]
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/05/logo-upv-horizontal.png)
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/06/logos-perte-chip-1024x119.png)
#
#
# # Laboratory 1. Waveguides

# %% [markdown]
# Welcome to our Photonic Integrated Circuits Laboratory! Throughout the course, we will be using a Python package called [GDSFactory](https://gdsfactory.github.io/gdsfactory/index.html). This is an open-source tool, and is a great alternative to other commercial software like Synopsys Optodesigner, Luceda Photonics, or Lumerical/Interconnect. Since it runs on Python, you have two options for executing your laboratory tasks:
#
# 1. **Local installation on your own PC** (Recommended): Please note that we will not spend class time on installing the software. However, feel free to reach out if you need help with the installation.
#
# 2. **Cloud Workspace**: Alternatively, you can use a cloud-based solution if the Local installation does not work.

# %% [markdown]
# ## 0. Imports

# %% [markdown]
# For this laboratory you will need the following libraries:

# %%
import matplotlib.pyplot as plt
import numpy as np

import tidy3d as td

import gplugins as gp
import gplugins.tidy3d as gt
from gplugins import plot
from gplugins.common.config import PATH

nm = 1e-3
wavelength = np.linspace(1500, 1600,11) * nm
f = td.C_0 / wavelength

# %% [markdown]
# ## LO.1. Effective index of a waveguide
#
# ### 1.1. Materials
#
# We need the refractive index of each material in the cross-section. There are different options to get this information, such as [RefractiveIndex.info](https://refractiveindex.info/) and the [Material Library from Tidy3D](https://docs.flexcompute.com/projects/tidy3d/en/v2.6.0/api/material_library.html#). Here we will load and check the characteristics from the most common materials used in fabrication of photonic circuits: **silicon (Si), silicon nitride (SiNx) and silicon dioxide (SiO2)**.

# %% [markdown]
# #### 1.1.1. Crystalline Silicon

# %%
## Material model loaded
si_complex = td.material_library["cSi"]["Li1993_293K"].eps_model(f)
## Check the Tidy3D Docs for more information on the "Variant"

## Index at a particular wavelength
si_index , si_k = td.Medium.eps_complex_to_nk(si_complex)
plt.scatter(wavelength, si_index,edgecolors='k',facecolors='none')
plt.plot(wavelength,si_index)
plt.title("Silicon refractive index")
plt.xlabel("Wavelength (um)")
plt.ylabel("n")
plt.grid()

# %% [markdown]
# #### 1.1.2. Silicon Nitride

# %%
nitride_complex = td.material_library["Si3N4"]["Luke2015PMLStable"].eps_model(f)
nitride_index, nitride_k = td.Medium.eps_complex_to_nk(nitride_complex)
plt.scatter(wavelength,nitride_index,edgecolors='k',facecolors='none')
plt.plot(wavelength, nitride_index)
plt.title("Silicon nitride refractive index")
plt.xlabel("Wavelength (um)")
plt.ylabel("n")
plt.grid()

# %% [markdown]
# #### 1.1.3. Silicon Dioxide

# %%
box_complex = td.material_library["SiO2"]["Horiba"].eps_model(f)
box_index, box_k = td.Medium.eps_complex_to_nk(box_complex)
plt.scatter(wavelength,box_index,edgecolors='k',facecolors='None')
plt.plot(wavelength, box_index)
plt.title("SiO2 refractive index")
plt.xlabel("Wavelength (um)")
plt.ylabel("n")
plt.grid()

# %% [markdown]
# ### 1.2. Cross - Section Definition
#
# In GDSFactory - Tidy3d modesolver we just have to use the [gt.modes.Waveguide()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.Waveguide.html) function.
# It implements the **deep (rib)** and **shallow (ridge)** waveguide variants. The following example corresponds to a **deep** waveguide for the **silicon nitride** fabrication proccess, this means that the **cladding** material is silicon dioxide and the **core** material is silicon nitride. The waveguide dimensions are 300 nm (height) and 1.2 um (width). We will check it's behavior at 1.55 um.

# %%
deep_waveguide = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=1.2, # Waveguide width
    core_thickness=300 * nm, # Waveguide height 
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=1550 * nm, # Wavelength to simulate
    num_modes=4, # Targeted number of modes to find 
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
)

deep_waveguide.plot_index()

# %% [markdown]
# ### 1.3. Simulations
#
# #### 1.3.1. Numerical results
#
# We can find the effective index (n_eff), TE and TM fraction for each particular cross-section.

# %%
deep_waveguide.n_eff
# Out:
# /home/raul/cifoin-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/raul/cifoin-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/raul/cifoin-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/raul/cifoin-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 09:30:54 CET WARNING: Mode field at frequency index 0, mode index 2 does not
#              decay at the plane boundaries.
# 09:30:55 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
#              WARNING: The group index was not computed. To calculate group
#              index, pass 'group_index_step = True' in the 'ModeSpec'.
# 2026-02-28 09:30:55.062 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_cf92515ae4232c65.npz.
# array([1.60524792+0.00010066j, 1.52829803+0.00017753j,
#        1.45072999+0.00019228j, 1.43325817+0.00021838j])

# %%
deep_waveguide.fraction_te
# Out:
# array([0.99505426, 0.01004259, 0.96264794, 0.047651  ])

# %%
deep_waveguide.fraction_tm
# Out:
# array([0.00494574, 0.98995741, 0.03735206, 0.952349  ])

# %% [markdown]
# #### 1.3.4. Plots

# %%
deep_waveguide.plot_field(mode_index=0 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                            cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-1.5, 1.5), # Set the x and y limits
                          ylim=(-0.7, 1)
) # 
plt.title('Titulo') # You might need this later :)
# Out:
# Text(0.5, 1.0, 'Titulo')

# %%
deep_waveguide.plot_field(mode_index=1 , # Mode to be plotted
                          field_name='Ey', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-1.5, 1.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
deep_waveguide.plot_field(mode_index=2 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-1.5, 1.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
deep_waveguide.plot_field(mode_index=3, # Mode to be plotted
                          field_name='Ey', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-1.5, 1.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %% [markdown]
# **Important**
# These results are derived from a numerical method used to solve the EM problem, so they must always be interpreted carefully to assess their accuracy. You must check, for instance, if the value of each index neff is higher than the refractive index of the cladding.

# %% [markdown]
# ## LO.2. Wavelength behavior

# %% [markdown]
# - Let's find the wavelength dependence of the effective index of the SiNx deep waveguide described in LO1. Change the wavelength used at the waveguide cross-section function, it could be a vector also.

# %%
# The wavelength could be a vector also
wavelength = np.linspace(1.5, 1.6, 100) # Student code here. Tip np.linspace()

deep_waveguide = gt.modes.Waveguide(
    wavelength=wavelength, 
    core_width=1.2, 
    slab_thickness=0.0,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    num_modes=4,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.2,
    grid_resolution=20, 
)

res_neff = deep_waveguide.n_eff # In this case, the result is not just a number, is a wavelength-dependent vector
res_te = deep_waveguide.fraction_te # Wavelength-dependent vector
res_tm =deep_waveguide.fraction_tm # Wavelength-dependent vector



plt.figure(figsize=(10, 5))
for k in range(res_neff.shape[1]):
    # It's necessary to 'access' each element on the array
    plt.scatter(wavelength, res_neff[:,k].real,edgecolors='k',facecolors='none',label = '__nolegend__')
    plt.plot(wavelength, res_neff[:,k].real,label=f'Mode {k}')
plt.title(f"Deep waveguide width={1.2}")
plt.xlabel("Wavelength (um)")
plt.ylabel("neff")
plt.grid()
# Common error: The box index variable was created in a previous cell. Check the dimensions match 
# with the newly created wavelength vector, or re-calculate the box index for the new one. 
f = td.C_0 / wavelength
box_complex = td.material_library["SiO2"]["Horiba"].eps_model(f)
box_index, box_k = td.Medium.eps_complex_to_nk(box_complex)
plt.plot(wavelength, box_index,'k--', label='SiO2 index') 
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout(rect=[0, 0, 0.85, 1])
# Out:
# 2026-02-28 09:37:55.832 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ec785d26342315ad.npz.

# %%
# Slab waveguide
wavelength = np.linspace(1.5, 1.6, 100) # Student code here. Tip np.linspace()

slab_waveguide = gt.modes.Waveguide(
    wavelength=wavelength, 
    core_width=1.2, 
    slab_thickness=150 * nm,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    num_modes=4,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.2,
    grid_resolution=20, 
)

res_neff = slab_waveguide.n_eff # In this case, the result is not just a number, is a wavelength-dependent vector
res_te = slab_waveguide.fraction_te # Wavelength-dependent vector
res_tm =slab_waveguide.fraction_tm # Wavelength-dependent vector

plt.figure(figsize=(10, 5))
for k in range(res_neff.shape[1]):
    # It's necessary to 'access' each element on the array
    plt.scatter(wavelength, res_neff[:,k].real,edgecolors='k',facecolors='none',label = '__nolegend__')
    plt.plot(wavelength, res_neff[:,k].real,label=f'Mode {k}')
plt.title(f"Slab waveguide width={1.2}")
plt.xlabel("Wavelength (um)")
plt.ylabel("neff")
plt.grid()
# Common error: The box index variable was created in a previous cell. Check the dimensions match 
# with the newly created wavelength vector, or re-calculate the box index for the new one.
f = td.C_0 / wavelength
box_complex = td.material_library["SiO2"]["Horiba"].eps_model(f)
box_index, box_k = td.Medium.eps_complex_to_nk(box_complex) 
plt.plot(wavelength, box_index,'k--', label='SiO2 index') 
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout(rect=[0, 0, 0.85, 1])
# Out:
# 2026-02-28 09:41:59.323 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_54f93b93b7b96fc1.npz.

# %%
slab_waveguide.plot_index()

# %% [markdown]
# - Repeat the analysis for a **shallow**ly etched waveguide with a 150 nm slab heigth.

# %% [markdown]
# ## LO.3. Width dependence

# %% [markdown]
# - Perform a sweep of the **deep** waveguide width. Use the code provided in the following cell or program your own sweep.

# %%
wavelength = 1.55 # Student code here

deep_waveguide = gt.modes.Waveguide(
    wavelength=wavelength,
    core_width=1.2,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    slab_thickness=0 * nm,
    num_modes=4,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.2,
    grid_resolution=20, 
)

w = np.linspace(0.6, 1.6, 100) # Student code here

sweep_neff = gt.modes.sweep_n_eff(deep_waveguide, 
                             core_width=w)

sweep_tefraction = gt.modes.sweep_fraction_te(deep_waveguide,
                                              core_width=w)

plt.figure(figsize=(10, 5))
for k in range(sweep_neff.shape[1]):
    plt.scatter(w, sweep_neff[:,k].real,edgecolors='k',c=sweep_tefraction.sel(mode_index=k),vmin=0, vmax=1,label = '__nolegend__',cmap='bwr')
    plt.plot(w, sweep_neff[:,k].real,label=f'Mode {k}')

plt.title("Deep waveguide width sweep - 1550nm")
plt.xlabel("Width (um)")
plt.ylabel("neff")
plt.grid()
plt.hlines(np.mean(box_index), xmin=np.min(w), xmax=np.max(w), colors='k', linestyles='dashed',label='SiO2 index')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout(rect=[0, 0, 0.85, 1])
plt.colorbar(orientation='horizontal',fraction=0.04).set_label("TE fraction")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 2026-02-28 09:46:15.663 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_e0f2a62752cad497.npz.
# 2026-02-28 09:46:15.666 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_e47f66408294b034.npz.
# 2026-02-28 09:46:15.668 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_03e13c7b22a79fc3.npz.
# 2026-02-28 09:46:15.670 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5a1ad9380a7cfe11.npz.
# 2026-02-28 09:46:15.672 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ca59e7429d26d4e9.npz.
# 2026-02-28 09:46:15.674 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_88654090b64b58de.npz.
# 2026-02-28 09:46:15.676 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_7b3bc228dc9f5ad7.npz.
# 2026-02-28 09:46:15.678 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_f354bf9c91a4853d.npz.
# 2026-02-28 09:46:15.680 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8d5818c9f0f71ebb.npz.
# 2026-02-28 09:46:15.682 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_c8cb73be836992d5.npz.
# 2026-02-28 09:46:15.683 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_1571cadcdfe03959.npz.
# 2026-02-28 09:46:15.685 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_3ae06f0e9b897b42.npz.
# 2026-02-28 09:46:15.686 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_88cb8d439a5110ff.npz.
# 2026-02-28 09:46:15.689 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_135fb88aa9e11292.npz.
# 2026-02-28 09:46:15.690 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_0b5a0f2665922f00.npz.
# 2026-02-28 09:46:15.692 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_c377f94d22c42fd9.npz.
# 2026-02-28 09:46:15.694 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_90ff7d02076fa898.npz.
# 2026-02-28 09:46:15.695 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5c97c731f3075dd8.npz.
# 2026-02-28 09:46:15.697 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_04edb366bedd4d73.npz.
# 2026-02-28 09:46:15.699 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_982fee6615620c02.npz.
# 2026-02-28 09:46:15.702 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_75ea077670cd3def.npz.
# 2026-02-28 09:46:15.704 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8482c22a4281bf68.npz.
# 2026-02-28 09:46:15.706 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_423ace54e9018435.npz.
# 2026-02-28 09:46:15.708 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_6dd83006d07b3803.npz.
# 2026-02-28 09:46:15.709 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_3369e99c5603f2ac.npz.
# 2026-02-28 09:46:15.711 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_20f32ac09086065e.npz.
# 2026-02-28 09:46:15.713 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_fd51f7e8664bf96d.npz.
# 2026-02-28 09:46:15.716 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_69958562229864cd.npz.
# 2026-02-28 09:46:15.718 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_2c93e4714e886f09.npz.
# 2026-02-28 09:46:15.720 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_09658ae65e9754e8.npz.
# 2026-02-28 09:46:15.721 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_d0886af0d5dc5699.npz.
# 2026-02-28 09:46:15.724 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4c93beb132b46dd2.npz.
# 2026-02-28 09:46:15.726 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5643516ee264a1ec.npz.
# 2026-02-28 09:46:15.728 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_13798a9e51464563.npz.
# 2026-02-28 09:46:15.731 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_9f8ebd195a57dec6.npz.
# 2026-02-28 09:46:15.733 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_b36279e3a198d0ec.npz.
# 2026-02-28 09:46:15.734 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_45006484cd8ddbe6.npz.
# 2026-02-28 09:46:15.736 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_88ef0baede450d52.npz.
# 2026-02-28 09:46:15.739 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_d796c6d64f281847.npz.
# 2026-02-28 09:46:15.740 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_73dc43a14e3ae6df.npz.
# 2026-02-28 09:46:15.743 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_95b5fff39dbd1246.npz.
# 2026-02-28 09:46:15.745 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4a54c76c6f029c8c.npz.
# 2026-02-28 09:46:15.747 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_562363ae42eecb73.npz.
# 2026-02-28 09:46:15.749 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8a52b286738433e1.npz.
# 2026-02-28 09:46:15.752 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_35d7de2456752077.npz.
# 2026-02-28 09:46:15.754 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a02895f75f451e52.npz.
# 2026-02-28 09:46:15.756 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_59eb6a53585ec194.npz.
# 2026-02-28 09:46:15.758 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_dc2029b1a828f0af.npz.
# 2026-02-28 09:46:15.758 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_54caf93cd7180c5b.npz.
# 2026-02-28 09:46:15.762 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_97f1db974233300d.npz.
# 2026-02-28 09:46:15.764 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_7baac8412981f178.npz.
# 2026-02-28 09:46:15.766 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_13f70b790224b6db.npz.
# 2026-02-28 09:46:15.769 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_668a91e41af080aa.npz.
# 2026-02-28 09:46:15.770 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4564810e79dc31f8.npz.
# 2026-02-28 09:46:15.773 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_012c271125817115.npz.
# 2026-02-28 09:46:15.775 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_95b972805b4788c4.npz.
# 2026-02-28 09:46:15.776 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_52a447bc0b2ced19.npz.
# 2026-02-28 09:46:15.779 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_252b940763cb1731.npz.
# 2026-02-28 09:46:15.780 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_fd7ad54168754de2.npz.
# 2026-02-28 09:46:15.782 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_471adb16420d0a26.npz.
# 2026-02-28 09:46:15.784 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ea0ddb32ef08c645.npz.
# 2026-02-28 09:46:15.787 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_b7f42432545c8b1a.npz.
# 2026-02-28 09:46:15.789 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_9c6c66663b3c563b.npz.
# 2026-02-28 09:46:15.790 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_50f92c0122ccbde9.npz.
# 2026-02-28 09:46:15.792 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_3949eb0c28bae389.npz.
# 2026-02-28 09:46:15.794 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_599413c6ed801823.npz.
# 2026-02-28 09:46:15.797 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_1e23c9d166e3aaff.npz.
# 2026-02-28 09:46:15.798 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4b487f32c078afac.npz.
# 2026-02-28 09:46:15.800 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_94778b4a7f8529e3.npz.
# 2026-02-28 09:46:15.802 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_294f06c36c46e148.npz.
# 2026-02-28 09:46:15.804 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a708d156cc755909.npz.
# 2026-02-28 09:46:15.805 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_54b9f98b679d003c.npz.
# 2026-02-28 09:46:15.807 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8018b110fa5b87db.npz.
# 2026-02-28 09:46:15.809 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_44b813dc24911702.npz.
# 2026-02-28 09:46:15.811 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_695013db75f176f5.npz.
# 2026-02-28 09:46:15.813 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a57c58617774181e.npz.
# 2026-02-28 09:46:15.815 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a205068a090dd148.npz.
# 2026-02-28 09:46:15.817 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_7305bddb54556681.npz.
# 2026-02-28 09:46:15.819 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5f3685c25c12876a.npz.
# 2026-02-28 09:46:15.820 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8d8ca64115d89f3e.npz.
# 2026-02-28 09:46:15.823 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ab7d844c39ea5be5.npz.
# 2026-02-28 09:46:15.825 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ac48de14ef0152ce.npz.
# 2026-02-28 09:46:15.827 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_72efa154efeaa1e4.npz.
# 2026-02-28 09:46:15.829 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_d099de656efd62ca.npz.
# 2026-02-28 09:46:15.831 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8fc8989364b4d53e.npz.
# 2026-02-28 09:46:15.833 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a2da4017bd2e1d6f.npz.
# 2026-02-28 09:46:15.835 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_89c4573505c312d8.npz.
# 2026-02-28 09:46:15.837 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_99ed6f6b48466474.npz.
# 2026-02-28 09:46:15.840 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_f003a8e73ba38206.npz.
# 2026-02-28 09:46:15.842 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_59159aa961638f60.npz.
# 2026-02-28 09:46:15.844 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_baee1ef2ad5c2a71.npz.
# 2026-02-28 09:46:15.846 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_607610c22dd6d183.npz.
# 2026-02-28 09:46:15.848 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_6394d21b877554b4.npz.
# 2026-02-28 09:46:15.851 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_05b5a516542fe067.npz.
# 2026-02-28 09:46:15.853 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_b8693f0be4050bb1.npz.
# 2026-02-28 09:46:15.855 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_70f569fefaa46356.npz.
# 2026-02-28 09:46:15.857 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_eef48ff8e1e84d85.npz.
# 2026-02-28 09:46:15.859 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_e3f5d4c67e15985f.npz.
# 2026-02-28 09:46:15.861 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a558d56405aae9af.npz.
# 2026-02-28 09:46:15.864 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_415c86fe948629a6.npz.
#   0%|          | 0/100 [00:00<?, ?it/s]
# 2026-02-28 09:46:15.873 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_e0f2a62752cad497.npz.
# 2026-02-28 09:46:15.877 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_e47f66408294b034.npz.
# 2026-02-28 09:46:15.879 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_03e13c7b22a79fc3.npz.
# 2026-02-28 09:46:15.881 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5a1ad9380a7cfe11.npz.
# 2026-02-28 09:46:15.883 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ca59e7429d26d4e9.npz.
# 2026-02-28 09:46:15.886 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_88654090b64b58de.npz.
# 2026-02-28 09:46:15.888 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_7b3bc228dc9f5ad7.npz.
# 2026-02-28 09:46:15.889 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_f354bf9c91a4853d.npz.
# 2026-02-28 09:46:15.892 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8d5818c9f0f71ebb.npz.
# 2026-02-28 09:46:15.895 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_c8cb73be836992d5.npz.
# 2026-02-28 09:46:15.897 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_1571cadcdfe03959.npz.
# 2026-02-28 09:46:15.899 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_3ae06f0e9b897b42.npz.
# 2026-02-28 09:46:15.902 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_88cb8d439a5110ff.npz.
# 2026-02-28 09:46:15.904 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_135fb88aa9e11292.npz.
# 2026-02-28 09:46:15.905 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_0b5a0f2665922f00.npz.
# 2026-02-28 09:46:15.907 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_c377f94d22c42fd9.npz.
# 2026-02-28 09:46:15.910 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_90ff7d02076fa898.npz.
# 2026-02-28 09:46:15.913 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5c97c731f3075dd8.npz.
# 2026-02-28 09:46:15.915 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_04edb366bedd4d73.npz.
# 2026-02-28 09:46:15.917 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_982fee6615620c02.npz.
# 2026-02-28 09:46:15.919 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_75ea077670cd3def.npz.
# 2026-02-28 09:46:15.921 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8482c22a4281bf68.npz.
# 2026-02-28 09:46:15.923 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_423ace54e9018435.npz.
# 2026-02-28 09:46:15.926 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_6dd83006d07b3803.npz.
# 2026-02-28 09:46:15.928 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_3369e99c5603f2ac.npz.
# 2026-02-28 09:46:15.929 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_20f32ac09086065e.npz.
# 2026-02-28 09:46:15.931 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_fd51f7e8664bf96d.npz.
# 2026-02-28 09:46:15.934 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_69958562229864cd.npz.
# 2026-02-28 09:46:15.935 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_2c93e4714e886f09.npz.
# 2026-02-28 09:46:15.937 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_09658ae65e9754e8.npz.
# 2026-02-28 09:46:15.940 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_d0886af0d5dc5699.npz.
# 2026-02-28 09:46:15.942 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4c93beb132b46dd2.npz.
# 2026-02-28 09:46:15.943 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5643516ee264a1ec.npz.
# 2026-02-28 09:46:15.946 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_13798a9e51464563.npz.
# 2026-02-28 09:46:15.948 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_9f8ebd195a57dec6.npz.
# 2026-02-28 09:46:15.949 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_b36279e3a198d0ec.npz.
# 2026-02-28 09:46:15.952 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_45006484cd8ddbe6.npz.
# 2026-02-28 09:46:15.954 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_88ef0baede450d52.npz.
# 2026-02-28 09:46:15.957 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_d796c6d64f281847.npz.
# 2026-02-28 09:46:15.959 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_73dc43a14e3ae6df.npz.
# 2026-02-28 09:46:15.960 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_95b5fff39dbd1246.npz.
# 2026-02-28 09:46:15.963 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4a54c76c6f029c8c.npz.
# 2026-02-28 09:46:15.964 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_562363ae42eecb73.npz.
# 2026-02-28 09:46:15.967 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8a52b286738433e1.npz.
# 2026-02-28 09:46:15.969 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_35d7de2456752077.npz.
# 2026-02-28 09:46:15.972 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a02895f75f451e52.npz.
# 2026-02-28 09:46:15.973 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_59eb6a53585ec194.npz.
# 2026-02-28 09:46:15.975 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_dc2029b1a828f0af.npz.
# 2026-02-28 09:46:15.979 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_54caf93cd7180c5b.npz.
# 2026-02-28 09:46:15.981 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_97f1db974233300d.npz.
# 2026-02-28 09:46:15.984 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_7baac8412981f178.npz.
# 2026-02-28 09:46:15.986 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_13f70b790224b6db.npz.
# 2026-02-28 09:46:15.990 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_668a91e41af080aa.npz.
# 2026-02-28 09:46:15.993 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4564810e79dc31f8.npz.
# 2026-02-28 09:46:15.995 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_012c271125817115.npz.
# 2026-02-28 09:46:15.997 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_95b972805b4788c4.npz.
# 2026-02-28 09:46:16.000 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_52a447bc0b2ced19.npz.
# 2026-02-28 09:46:16.004 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_252b940763cb1731.npz.
# 2026-02-28 09:46:16.007 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_fd7ad54168754de2.npz.
# 2026-02-28 09:46:16.010 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_471adb16420d0a26.npz.
# 2026-02-28 09:46:16.012 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ea0ddb32ef08c645.npz.
# 2026-02-28 09:46:16.014 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_b7f42432545c8b1a.npz.
# 2026-02-28 09:46:16.017 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_9c6c66663b3c563b.npz.
# 2026-02-28 09:46:16.019 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_50f92c0122ccbde9.npz.
# 2026-02-28 09:46:16.020 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_3949eb0c28bae389.npz.
# 2026-02-28 09:46:16.022 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_599413c6ed801823.npz.
# 2026-02-28 09:46:16.025 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_1e23c9d166e3aaff.npz.
# 2026-02-28 09:46:16.028 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4b487f32c078afac.npz.
# 2026-02-28 09:46:16.030 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_94778b4a7f8529e3.npz.
# 2026-02-28 09:46:16.032 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_294f06c36c46e148.npz.
# 2026-02-28 09:46:16.034 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a708d156cc755909.npz.
# 2026-02-28 09:46:16.036 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_54b9f98b679d003c.npz.
# 2026-02-28 09:46:16.038 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8018b110fa5b87db.npz.
# 2026-02-28 09:46:16.040 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_44b813dc24911702.npz.
# 2026-02-28 09:46:16.042 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_695013db75f176f5.npz.
# 2026-02-28 09:46:16.044 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a57c58617774181e.npz.
# 2026-02-28 09:46:16.046 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a205068a090dd148.npz.
# 2026-02-28 09:46:16.048 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_7305bddb54556681.npz.
# 2026-02-28 09:46:16.050 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5f3685c25c12876a.npz.
# 2026-02-28 09:46:16.052 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8d8ca64115d89f3e.npz.
# 2026-02-28 09:46:16.054 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ab7d844c39ea5be5.npz.
# 2026-02-28 09:46:16.056 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ac48de14ef0152ce.npz.
# 2026-02-28 09:46:16.059 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_72efa154efeaa1e4.npz.
# 2026-02-28 09:46:16.061 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_d099de656efd62ca.npz.
# 2026-02-28 09:46:16.062 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8fc8989364b4d53e.npz.
# 2026-02-28 09:46:16.064 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a2da4017bd2e1d6f.npz.
# 2026-02-28 09:46:16.066 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_89c4573505c312d8.npz.
# 2026-02-28 09:46:16.068 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_99ed6f6b48466474.npz.
# 2026-02-28 09:46:16.070 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_f003a8e73ba38206.npz.
# 2026-02-28 09:46:16.072 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_59159aa961638f60.npz.
# 2026-02-28 09:46:16.075 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_baee1ef2ad5c2a71.npz.
# 2026-02-28 09:46:16.076 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_607610c22dd6d183.npz.
# 2026-02-28 09:46:16.079 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_6394d21b877554b4.npz.
# 2026-02-28 09:46:16.080 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_05b5a516542fe067.npz.
# 2026-02-28 09:46:16.083 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_b8693f0be4050bb1.npz.
# 2026-02-28 09:46:16.085 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_70f569fefaa46356.npz.
# 2026-02-28 09:46:16.086 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_eef48ff8e1e84d85.npz.
# 2026-02-28 09:46:16.088 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_e3f5d4c67e15985f.npz.
# 2026-02-28 09:46:16.089 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a558d56405aae9af.npz.
# 2026-02-28 09:46:16.091 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_415c86fe948629a6.npz.

# %% [markdown]
# ## LO.4. Waveguide compact model

# %% [markdown]
# A compact model of an integrated photonic waveguide is a reduced-order mathematical model that describes the waveguide’s optical behavior—such as phase propagation, loss, and dispersion, using analytical or semi-analytical equations. Consider:
#
# Consider:

# %% [markdown]
# The transfer function for propagation in a waveguide:
#
# $$
# H(\lambda)
# = e^{-j\,\gamma(\lambda)\,z}
# = e^{-j\,\mathrm{Re}\{\gamma(\lambda)\}\,z}\,
#   e^{\mathrm{Im}\{\gamma(\lambda)\}\,z}.
# $$
#
# Where
#
# $$
# \beta(\lambda) = \mathrm{Re}\{\gamma(\lambda)\}\,z
# = \frac{2\pi}{\lambda}\,n_\mathrm{eff}(\lambda).
# $$
#
# Let's model the waveguide's effective index wavelength variation using a second order polynomial:
#
# $$
# n_\mathrm{eff}(\lambda)
# = n_{1} + n_{2}\,(\lambda-\lambda_{0}) + n_{3}\,(\lambda-\lambda_{0})^{2}
# $$
#
# Where
#
# 1.
# $$
# n_\mathrm{eff}(\lambda_0) = n_1
# $$
# 2.
# $$
# n_g(\lambda_0) = n_1 - n_2\,\lambda_0
# $$
# 3.
# $$
# D = -\frac{2\,\lambda_0\,n_3}{c}\;\;[\mathrm{s}^2/\mathrm{m}]
# $$
#
# - Find the values for n, ng and D of the following waveguides:
#     - Deep waveguide, height = 300nm, width = 1.2um
#     - Shallow waveguide, core height = 300nm, slab height = 150 nm, width = 1.2um
#
# **TIP**. Use the Lab0.1.Modesolver results (neff vs lambda) as starting point. Fit the results using a second order polynomial (with the lambda_0 shift) and relate the fit results to n_g and D values.

# %%
wavelength =  np.linspace(1.5,1.6,100)# Student code here. Tip np.linspace()
 
deep_waveguide = gt.modes.Waveguide(
   
    wavelength=wavelength,
    core_width=1.2,
    slab_thickness=0.0,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    num_modes=4,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.2,
    grid_resolution=20,
)
f = td.C_0 / wavelength
box_complex = td.material_library["SiO2"]["Horiba"].eps_model(f)
box_index, box_k = td.Medium.eps_complex_to_nk(box_complex)
 
res_neff = deep_waveguide.n_eff # In this case, the result is not just a number, is a wavelength-dependent vector
res_te = deep_waveguide.fraction_te # Wavelength-dependent vector
res_tm =deep_waveguide.fraction_tm # Wavelength-dependent vector
 
# --- Centro del ajuste ---
lambda0 = 1.55  # um
i0 = np.argmin(np.abs(wavelength - lambda0))
 
# --- Selección de TE0 / TM0 (si fraction_te/tm no permiten, usamos modo 0) ---
Nmodes = res_neff.shape[1]
Nlam = len(wavelength)
 
def pick_mode(frac_arr):
    frac_arr = np.array(frac_arr)
    if frac_arr.ndim == 2:                # (Nlam, Nmodes)
        return int(np.argmax(frac_arr[i0, :]))
    if frac_arr.ndim == 1 and frac_arr.shape[0] == Nmodes:  # (Nmodes,)
        return int(np.argmax(frac_arr))
    return 0  # fallback: modo fundamental
 
idx_TE0 = pick_mode(res_te)
idx_TM0 = pick_mode(res_tm)
 
neff_TE0 = res_neff[:, idx_TE0].real
neff_TM0 = res_neff[:, idx_TM0].real
 
# --- FIT 2º orden: neff = n1 + n2(λ-λ0) + n3(λ-λ0)^2 ---
def fit_poly2(neff_mode, wavelength_um, lambda0_um):
    dl = wavelength_um - lambda0_um
    n3, n2, n1 = np.polyfit(dl, neff_mode, 2)
    return n1, n2, n3
 
n1_te, n2_te, n3_te = fit_poly2(neff_TE0, wavelength, lambda0)
n1_tm, n2_tm, n3_tm = fit_poly2(neff_TM0, wavelength, lambda0)
 
# --- ng y D (según diapositiva) ---
c = td.C_0
lambda0_m = lambda0 * 1e-6
 
def calc_ng_D(lambda0_um, lambda0_m, n1, n2, n3):
    ng = n1 - lambda0_um * n2
    n3_m2 = n3 * 1e12  # 1/um^2 -> 1/m^2
    D = -(2 * lambda0_m * n3_m2) / c
    return ng, D
 
ng_te, D_te = calc_ng_D(lambda0, lambda0_m, n1_te, n2_te, n3_te)
ng_tm, D_tm = calc_ng_D(lambda0, lambda0_m, n1_tm, n2_tm, n3_tm)
 
print("\n=== DEEP waveguide compact model (w=1.2um, h=300nm, slab=0) ===")
print(f"TE0 (mode idx {idx_TE0}): n1={n1_te:.6f}, n2={n2_te:.6e}, n3={n3_te:.6e}, ng={ng_te:.6f}, D={D_te:.6e} [s/m^2]")
print(f"TM0 (mode idx {idx_TM0}): n1={n1_tm:.6f}, n2={n2_tm:.6e}, n3={n3_tm:.6e}, ng={ng_tm:.6f}, D={D_tm:.6e} [s/m^2]")
 
# --- DIBUJO SOLO DEL POLINOMIO (sin 100 puntos del solver) ---
w_fine = np.linspace(wavelength.min(), wavelength.max(), 600)
 
def poly_eval(w, lambda0_um, n1, n2, n3):
    dl = w - lambda0_um
    return n1 + n2*dl + n3*dl**2
 
neff_te_fit = poly_eval(w_fine, lambda0, n1_te, n2_te, n3_te)
neff_tm_fit = poly_eval(w_fine, lambda0, n1_tm, n2_tm, n3_tm)
 
plt.figure(figsize=(9,4.5))
plt.plot(w_fine, neff_te_fit, label="TE0: 2nd order polynomial fit")
plt.plot(w_fine, neff_tm_fit, label="TM0: 2nd order polynomial fit")
plt.title("Deep waveguide — compact model (TE0 & TM0)")
plt.xlabel("Wavelength (um)")
plt.ylabel("n_eff (fit)")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 2026-02-28 12:40:02.657 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ec785d26342315ad.npz.
#
# === DEEP waveguide compact model (w=1.2um, h=300nm, slab=0) ===
# TE0 (mode idx 0): n1=1.604917, n2=-2.161763e-01, n3=9.735802e-02, ng=1.939990, D=-1.006729e-09 [s/m^2]
# TM0 (mode idx 1): n1=1.527189, n2=-1.579414e-01, n3=1.538322e-01, ng=1.771998, D=-1.590700e-09 [s/m^2]

# %%
wavelength =  np.linspace(1.5,1.6,100)# Student code here. Tip np.linspace()
 
shallow_waveguide = gt.modes.Waveguide(
   
    wavelength=wavelength,
    core_width=1.2,
    slab_thickness=150 * nm,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    num_modes=4,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.2,
    grid_resolution=20,
)
f = td.C_0 / wavelength
box_complex = td.material_library["SiO2"]["Horiba"].eps_model(f)
box_index, box_k = td.Medium.eps_complex_to_nk(box_complex)
 
res_neff = shallow_waveguide.n_eff # In this case, the result is not just a number, is a wavelength-dependent vector
res_te = shallow_waveguide.fraction_te # Wavelength-dependent vector
res_tm =shallow_waveguide.fraction_tm # Wavelength-dependent vector
 
# --- Centro del ajuste ---
lambda0 = 1.55  # um
i0 = np.argmin(np.abs(wavelength - lambda0))
 
# --- Selección de TE0 / TM0 (si fraction_te/tm no permiten, usamos modo 0) ---
Nmodes = res_neff.shape[1]
Nlam = len(wavelength)
 
def pick_mode(frac_arr):
    frac_arr = np.array(frac_arr)
    if frac_arr.ndim == 2:                # (Nlam, Nmodes)
        return int(np.argmax(frac_arr[i0, :]))
    if frac_arr.ndim == 1 and frac_arr.shape[0] == Nmodes:  # (Nmodes,)
        return int(np.argmax(frac_arr))
    return 0  # fallback: modo fundamental
 
idx_TE0 = pick_mode(res_te)
idx_TM0 = pick_mode(res_tm)
 
neff_TE0 = res_neff[:, idx_TE0].real
neff_TM0 = res_neff[:, idx_TM0].real
 
# --- FIT 2º orden: neff = n1 + n2(λ-λ0) + n3(λ-λ0)^2 ---
def fit_poly2(neff_mode, wavelength_um, lambda0_um):
    dl = wavelength_um - lambda0_um
    n3, n2, n1 = np.polyfit(dl, neff_mode, 2)
    return n1, n2, n3
 
n1_te, n2_te, n3_te = fit_poly2(neff_TE0, wavelength, lambda0)
n1_tm, n2_tm, n3_tm = fit_poly2(neff_TM0, wavelength, lambda0)
 
# --- ng y D (según diapositiva) ---
c = td.C_0
lambda0_m = lambda0 * 1e-6
 
def calc_ng_D(lambda0_um, lambda0_m, n1, n2, n3):
    ng = n1 - lambda0_um * n2
    n3_m2 = n3 * 1e12  # 1/um^2 -> 1/m^2
    D = -(2 * lambda0_m * n3_m2) / c
    return ng, D
 
ng_te, D_te = calc_ng_D(lambda0, lambda0_m, n1_te, n2_te, n3_te)
ng_tm, D_tm = calc_ng_D(lambda0, lambda0_m, n1_tm, n2_tm, n3_tm)
 
print("\n=== DEEP waveguide compact model (w=1.2um, h=300nm, slab=0) ===")
print(f"TE0 (mode idx {idx_TE0}): n1={n1_te:.6f}, n2={n2_te:.6e}, n3={n3_te:.6e}, ng={ng_te:.6f}, D={D_te:.6e} [s/m^2]")
print(f"TM0 (mode idx {idx_TM0}): n1={n1_tm:.6f}, n2={n2_tm:.6e}, n3={n3_tm:.6e}, ng={ng_tm:.6f}, D={D_tm:.6e} [s/m^2]")
 
# --- DIBUJO SOLO DEL POLINOMIO (sin 100 puntos del solver) ---
w_fine = np.linspace(wavelength.min(), wavelength.max(), 600)
 
def poly_eval(w, lambda0_um, n1, n2, n3):
    dl = w - lambda0_um
    return n1 + n2*dl + n3*dl**2
 
neff_te_fit = poly_eval(w_fine, lambda0, n1_te, n2_te, n3_te)
neff_tm_fit = poly_eval(w_fine, lambda0, n1_tm, n2_tm, n3_tm)
 
plt.figure(figsize=(9,4.5))
plt.plot(w_fine, neff_te_fit, label="TE0: 2nd order polynomial fit")
plt.plot(w_fine, neff_tm_fit, label="TM0: 2nd order polynomial fit")
plt.title("Deep waveguide — compact model (TE0 & TM0)")
plt.xlabel("Wavelength (um)")
plt.ylabel("n_eff (fit)")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 2026-02-28 12:50:32.793 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_54f93b93b7b96fc1.npz.
#
# === DEEP waveguide compact model (w=1.2um, h=300nm, slab=0) ===
# TE0 (mode idx 3): n1=1.526537, n2=-1.239965e-01, n3=4.246924e-02, ng=1.718731, D=-4.391526e-10 [s/m^2]
# TM0 (mode idx 2): n1=1.536102, n2=-1.386659e-01, n3=9.793480e-02, ng=1.751034, D=-1.012694e-09 [s/m^2]

# %% [markdown]
# ## LO.5. Bend waveguide radius vs. loss – deep

# %% [markdown]
# The bend loss has three primary contributions:
#
# 1. Mode-mismatch loss
# 2. Radiation loss
# 3. Propagation loss

# %%
bend_1550 = gt.modes.Waveguide(
    wavelength=1550 * nm,
    core_width=1.2,
    slab_thickness=0.0,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    num_modes=1,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.2,
    grid_resolution=30, 
    bend_radius=20, # Bend radius
)

bend_1550.plot_field(field_name="Ex", 
                     mode_index=0, # Field to be plotted
                     value='real', # Real - abs - imag
                     cmap='coolwarm',
                     xlim=(-1.5, 1.5), # Set the x and y limits
                     ylim=(-0.7, 1))

# %% [markdown]
# ### Mode-mismatch loss
#
# Bend waveguide mode differs slightly from the straight waveguide mode, wich yield into mode-convertion losses. We can calculate this factor with as the overlap of the latter two modes.
#
# This is already implemented on GDSfactory library:

# %%
radii = np.arange(20.0, 120,11)

mismatch = gt.modes.sweep_bend_mismatch(bend_1550, radii)

plt.plot(radii, 10 * np.log10(mismatch))
plt.title("Strip waveguide bend")
plt.xlabel("Radius (μm)")
plt.ylabel("Mismatch (dB)")

# %% [markdown]
# ### Propagation loss
#
# Consider the equivalent linear length of the quarter-circle bend. Light will attenuate following a trend quantified with the experimentally measured parameter $$\alpha [\mathrm{dB}/\mathrm{cm}]$$. It depends on the fabrication process mainly. We will add this loss (in dBs) to the mode-mismatch loss to calculate the total loss per bend.
#
# *We are not considering the radiation losses, mainly because is not easy to implement a quick simulation for this parameter. Under certain conditions, the main loss sources are the ones considered in this example

# %%
dB_cm = 1.5  # dB/cm Technology loss - 
length = 0.5 * np.pi * radii * 1e-6
propagation_loss = dB_cm * length * 1e2
propagation_loss

plt.title("Bend loss for TE polarization")
plt.plot(radii, -10 * np.log10(mismatch), ".", label="Mode loss")
plt.plot(radii, propagation_loss, ".", label="Propagation loss")
plt.plot(radii, propagation_loss-10 * np.log10(mismatch), ".", label="Total loss")
plt.xlabel("Bend radius (um)")
plt.ylabel("Loss (dB)")
plt.legend()

# %% [markdown]
# - Use the code provided in this section to calculate the safe radius for 1.2 um width deep waveguides at 1.5 um. Consider safe means less than 0.1 dB/90º

# %% [markdown]
# ## EXTRA
#
# All the past simulations were done considering as core material de Silicon Nitride (SiNx) and Silicon Dioxide (SiO2) as cladding material. Now, **simulate the Silicon-On-Insulator technology changing the core material to Silicon (Si)**. In this case, the dimensions will be 220 nm heigth and 500 nm width.
# 1. Repeat the LO.2. wavelength behavior simulations, considering the updated materials and dimensions.
# 2. Repeat the LO.3. width dependence analysis, now sweeping in a 300nm - 1um range.
# 3. Find the safe radius for this technology. Consider sweeping the radius in a 5um to 30um range.
# 4. **Compare the SiNx and SOI technologies**

# %% [markdown]
# ## Grading
#
# LO.1. 1 Point <br>
# LO.2. 2 Points <br>
# LO.3. 1 Point <br>
# LO.4. 2 Points <br>
# LO.5. 1 Point <br>
# **Total 7 Points** <br>
# Extra (Up to) 3 Points
